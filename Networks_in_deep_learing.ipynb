# %% [markdown]
# <a href="https://colab.research.google.com/github/shareefat/Deep-Learing/blob/main/Networks_in_deep_learing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Deep Neural Networks
#
# - A deep Neural network (DNN) is an ANN with Multiple Hidden Layers B/W the input and the Output Layers DNNs can Model Complex Non linear Relationship
#
# - the main purpose is to recieve a set of input and perform complex calculations on them and give output to solve realworld problems
# - Neural networks are widely used in supervised learing and reinforcement learning problem
#
# - in deep learning the number of hidden layers mostly non linear can be large and about 1000 layers
#
# - we mostly use gradient decent methord for optimizing the network and minimising the loss function
#
# - training the data set forms an imp part and in addition Backpropogation is the main algo

# %% [markdown]
# ![WhatsApp Image 2025-01-28 at 12.00.13_dabec609.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - Neural network are functions that have input like X1,X2,X3 that are transformed to output like Z1,Z2,Z3 and so on
# - the weight and biased change layer to layer 'W' and 'V' are the weight or sysnapses of the layer

# %% [markdown]
# #Back propogation
#
# - Backpropogation is an algorithm in ai and ml to train ANN through error correction actualy it worked irrtratively by minimizing the cost function by adjusting the wights and biase

# %% [markdown]
# # RNN : Recurrent Neural Network
#
# - RNN are neral network in which data can flow in any direction this is used in language modeling or NLP
#
# - the basic concept is Utilizing sequencial information in normal neural network it asume that all input and output are independant of each other if they want to predict the next word it will look the previous word

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #CNN : Convolutional Neural Network
#
# - if we increase the numper if layers in a neura network to make it deeper it increase the complexity of the network and allow us to model funtions that are more complicated thee numbber of weight will exponentialy increase
#
# - CNN are extensivly used in cimputer vision have been applied also in acoustic modeling for automatic speech recognition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CNN will reduce the number of parameters that need to be tuned
#
# CNN process the image with various layers
#
# 1. connvolutional layer
# 2. Non linearity layer(activation Function)
# 3. Pooling layer(Down sampling)
# 4. Flattern layer
# 5. fully Connected layer : std NN used in classification

# %% [markdown]
# #Convolutional layer
# this layer is the main bulding block of CNN
#
# Responsible for receving the features of the picture
#
# This layer applies some filters to remove low and high level features in the image
#
# this filter is usually multi diamentional and contain pixal values

# %% [markdown]
# #non linearity layer
#
# Non linearity usualy comes after convolutional layers
#
# this layer is called activational layer bcz one of the activational function is used
#
# black value in the feature map are negative . after relu function it remove black and replace with 0

# %% [markdown]
# #Pooling layer
#
# - the pooling layer is commonly used to downsample the dimention of the feature maps

# %% [markdown]
# **Max pooling**
#
# - selects maximum element from region of fearure map
#
# **AVg Pooling**
#
# - compute the average of elements present in the region of feature map

# %% [markdown]
# #advantage of Pooling Layer
#
# 1. Dimensionality Reduction
# 2. Feature Selection
