# %% [markdown]
# <a href="https://colab.research.google.com/github/shareefat/Deep-Learing/blob/main/DL_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction to deep learning**
#
# deep learning is a branch of machine learning which is based on artificial neural network
#
# it is capable of learning complex patterns and relationship within data
#
# it has becoming poopular in recent years due to its advanced power and avaliability of large dataset.bcz it is based on artificial neural network(ANN)
#
#
# 1. deep leaning is subfield of machine learning that involves the usse of neural network to the model and solve complex models, this networks can learn complex representation of data by discoving heirarchical pattern and features from the data
#
#
# 2. deep learning has achived significant success in the field include image recognition ,NLP , speech recognition and recommentation system
#
#
# 3. Training deep learning model required large dataset

# %% [markdown]
# **WHAT IS DEEPLEARNING**
#
# deep learning is a branch of machine learning which is based on artificial neural network architecture. an artificial neural network uses the layer of interconnected nodes called neurons that work together to process and learn from the input data
#
#
# in a fully connected deep neural network there is input neurons, hiden layer and output nerons
#
# each neurons recives input from the previous neurons the final layer will produce the output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# deep learning became most popular area and visible area of machine learning due to its success in
#
#  applicatons such as
#
# **computer vision**
#
# **NLP**
#
# **Rain forcement**

# %% [markdown]
# # **Artificial Neural Network**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Artificial neurons also known as units the artificial nerons are arranged in a series of layer the complexity of of neural network will depend on the complexity of the dataset bcz a layer has dozens unit or million units
#
#
# commenly ANN have a input layer , output Layer , and Hidden Layer

# %% [markdown]
# Handwritern Notes image processing and finding the probability

# %% [markdown]
# ![handwritren image processesing.png](data:image/png;base64,...)

# %% [markdown]
# First the image convert to pixel and convert to 2d metrix
#
# convert the 2d metrix to 1d by flattern methord
#
# the 1d metrix values insert as input to ANN
#
# and check the probability

# %% [markdown]
# # Difference B/W Machine learning and Deep learning

# %% [markdown]
# # machine learning :
#
#
#
#
# 1.   apply statical algoritham
# 2.   Can work on small dataset
# 3.   better for the low label task
# 4. Takes less time for traing
# 5. a model is created by relevent features are manual
# 6. less complex compair to deep learning
# 7. it can  work on Cpu and less performance computer
#
#
#
# #Deep learning :
#
#
# 1.   uses artificial neural network
# 2.   required large number of data
# 3.   better for complex task like image processing , NLP
# 4.   takes more time to train
# 5.  Relevent features are automaticaly extracted
# 6. more complex than machine learning
# 7. it required high performnce with GPU

# %% [markdown]
# # Applications of Deep learning
#
# The main application of deep learning can be divided into computer vision , natural language processing, Reinforcement learning
#
#
# # 1. Computer Vision :
#  In computer vision , Deep learning Model can enable machine to identify and understand the visual data
#
#
#
#
# *   Object Detection
# *   Image classifier
# * image segmentaion
#
#
#
# # 2. NLP:
#  in NLP the model can enable machine to understand and generate human language
#
# * Automatic Text GEneration
# *language Translation
# *sentimental analysis
# *speech recognition
#
#
# #3. Reinforcement learing :
# in reinforcement learinng deep learning work as training agent to take action in environment to maximize a reward
#
# * Game playing
# *Robotics
# *Control system

# %% [markdown]
# #challenges in deep learing
#
# 1. data availability
# 2. computation Resource : it required specialized hardware Like GPU , TPU
# 3. time Consuming
# 4. Interpretability
# 5. Overfitting

# %% [markdown]
# #TYPE OF NEURAL NETWORK
# Deep learing models are able to automaticaly learn features the data which make them well suited for tasks such as image recognition , speech recognition and NLP
#
# #* FeedForward Neural network(FNN):
# are the simplest type of ANN FNN is widely used for image classification, speech recognition and NLP
# #* Convolutional Neural Network(CNN):
#  for Specially for Image and Video recognition task
# #*Recurrent Newral Network(RNN) :
# type of neural network to process sequantial data such as time series and NLP
# suitable for NLP, speech recognition and language translation

# %% [markdown]
# #ADVANTAGES OF DEEP LEARNING
# high accuracy for image recognition and NLP
#
# 1. automated feature engineering
# 2. scalability
# 3. flexibility
# 4. continoal improvement : deep learning model can continual improve their performance as becoming available

# %% [markdown]
# #DISADVANTAGES OF DEEP LEARNING
#
# 1. high computational time
# 2. need large dataset
# 3.overfitting
# 4.interpretability
# 5.black box : it is difficult to explain what is happening inside the model during that work

# %% [markdown]
# # House price prediction USING artificial neural network(ANN)

# %% [markdown]
# ![handwritren image processesing.png](data:image/png;base64,...)

# %% [markdown]
# #ANN REPRESENTATON OF SINGLE NEURON

# %% [markdown]
# ![handwritren image processesing.png](data:image/png;base64,...)
